# %%
conda install -c anaconda javabridge
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda3
#
#   added / updated specs:
#     - javabridge
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _ipyw_jlab_nb_ext_conf-0.1.0|           py36_0           4 KB  anaconda
#     alabaster-0.7.12           |           py36_0          17 KB  anaconda
#     anaconda-client-1.7.2      |           py36_0         141 KB  anaconda
#     anaconda-navigator-1.9.7   |           py36_0         4.8 MB  anaconda
#     anaconda-project-0.8.2     |           py36_0         478 KB  anaconda
#     appnope-0.1.0              |   py36hf537a9a_0           8 KB  anaconda
#     appscript-1.1.0            |   py36h1de35cc_0         271 KB  anaconda
#     asn1crypto-0.24.0          |           py36_0         154 KB  anaconda
#     astroid-2.2.5              |           py36_0         280 KB  anaconda
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import roc_curve, roc_auc_score,auc


#reading the data
class_1=pd.read_csv("./FCM-Models-Results/tree-six-roc.arff.csv")
class_2=pd.read_csv("./FCM-Models-Results/tree-sixteen-roc.arff.csv")
class_3=pd.read_csv("./FCM-Models-Results/tree-twentyfour-roc.arff.csv")

#class 1 true positive rata and false positive rate
fpr_1=class_1["'False Positive Rate'"]
tpr_1=class_1["'True Positive Rate'"]

#class 2 true positive rata and false positive rate
fpr_2=class_2["'False Positive Rate'"]
tpr_2=class_2["'True Positive Rate'"]
fpr_3=class_3["'False Positive Rate'"]
tpr_3=class_3["'True Positive Rate'"]
##class 1 AUC (Area under Curve)
class_1_area=auc(fpr_1,tpr_1)

##class 2 AUC (Area under Curve)
class_2_area=auc(fpr_2,tpr_2)
class_3_area=auc(fpr_3,tpr_3)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(fpr_1, tpr_1,  color='darkorange', label='Class:Age 6 months(AUC = % 0.3f)' % class_1_area)
plt.plot(linestyle='**')
plt.plot(fpr_2, tpr_2, color='b',label='Class:Age 16 months (AUC = % 0.3f)' % class_2_area)
plt.plot(linestyle='..')
plt.plot(fpr_3, tpr_3, color='g',label='Class:Age 24 months (AUC = % 0.3f)' % class_3_area)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC and AUC for Decision Tree ", fontdict=None, loc='center', pad=None)
plt.legend(loc="lower right")
plt.savefig("roc-decisionTree",  dpi=100)
plt.show()

# %%
#reading the data
class_1=pd.read_csv("./FCM-Models-Results/ibk-six-roc.arff.csv")
class_2=pd.read_csv("./FCM-Models-Results/ibk-sixteen-roc.arff.csv")
class_3=pd.read_csv("./FCM-Models-Results/ibk-twentyfour-roc.arff.csv")

#class 1 true positive rata and false positive rate
fpr_1=class_1["'False Positive Rate'"]
tpr_1=class_1["'True Positive Rate'"]

#class 2 true positive rata and false positive rate
fpr_2=class_2["'False Positive Rate'"]
tpr_2=class_2["'True Positive Rate'"]
fpr_3=class_3["'False Positive Rate'"]
tpr_3=class_3["'True Positive Rate'"]
##class 1 AUC (Area under Curve)
class_1_area=auc(fpr_1,tpr_1)

##class 2 AUC (Area under Curve)
class_2_area=auc(fpr_2,tpr_2)
class_3_area=auc(fpr_3,tpr_3)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(fpr_1, tpr_1,  color='darkorange', label='Class:Age 6 months(AUC = % 0.3f)' % class_1_area)
plt.plot(linestyle='**')
plt.plot(fpr_2, tpr_2, color='b',label='Class:Age 16 months (AUC = % 0.3f)' % class_2_area)
plt.plot(linestyle='..')
plt.plot(fpr_3, tpr_3, color='g',label='Class:Age 24 months (AUC = % 0.3f)' % class_3_area)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC and AUC for 3 Nearest Neighbor ", fontdict=None, loc='center', pad=None)
plt.legend(loc="lower right")
plt.savefig("roc-knn",  dpi=100)
plt.show()

# %%
#reading the data
class_1=pd.read_csv("./FCM-Models-Results/SMO-six-roc.arff.csv")
class_2=pd.read_csv("./FCM-Models-Results/SMO-sixteen-roc.arff.csv")
class_3=pd.read_csv("./FCM-Models-Results/SMO-twentyfour-roc.arff.csv")

#class 1 true positive rata and false positive rate
fpr_1=class_1["'False Positive Rate'"]
tpr_1=class_1["'True Positive Rate'"]

#class 2 true positive rata and false positive rate
fpr_2=class_2["'False Positive Rate'"]
tpr_2=class_2["'True Positive Rate'"]
fpr_3=class_3["'False Positive Rate'"]
tpr_3=class_3["'True Positive Rate'"]
##class 1 AUC (Area under Curve)
class_1_area=auc(fpr_1,tpr_1)

##class 2 AUC (Area under Curve)
class_2_area=auc(fpr_2,tpr_2)
class_3_area=auc(fpr_3,tpr_3)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(fpr_1, tpr_1,  color='darkorange', label='Class:Age 6 months(AUC = % 0.3f)' % class_1_area)
plt.plot(linestyle='**')
plt.plot(fpr_2, tpr_2, color='b',label='Class:Age 16 months (AUC = % 0.3f)' % class_2_area)
plt.plot(linestyle='..')
plt.plot(fpr_3, tpr_3, color='g',label='Class:Age 24 months (AUC = % 0.3f)' % class_3_area)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC and AUC for SMO ", fontdict=None, loc='center', pad=None)
plt.legend(loc="lower right")
plt.savefig("roc-smo",  dpi=100)
plt.show()

# %%
import numpy as np


def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "blue")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "blue")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.savefig("cm-decisionTree",  dpi=100)
    plt.show()

# %%
plot_confusion_matrix(cm           = np.array([[ 5,  0,   10],
                                              [  0,  51,  0],
                                              [  0,  0, 49]]), 
                      normalize    = False,
                      target_names = ['Age 6 months ', 'Age 16 months', 'Age 24 months'],
                      title        = "Confusion Matrix: Decision Tree")

# %%
plot_confusion_matrix(cm           = np.array([[ 8,  0,   7],
                                              [  0,  51,  0],
                                              [  5,  0, 44]]), 
                      normalize    = False,
                      target_names = ['Age 6 months ', 'Age 16 months', 'Age 24 months'],
                      title        = "Confusion Matrix: 3 Nearest Neighbor")

# %%
plot_confusion_matrix(cm           = np.array([[ 8,  0,   7],
                                              [  0,  51,  0],
                                              [  2,  0, 47]]), 
                      normalize    = False,
                      target_names = ['Age 6 months ', 'Age 16 months', 'Age 24 months'],
                      title        = "Confusion Matrix: SMO")

# %%
from sklearn import*
import numpy as np
import matplotlib.pyplot as plt
from mlxtend.plotting import category_scatter
df=pd.read_csv("./FCM-UpdatedTrainSet.csv")


#fig, ax = plt.subplots(4, 1, constrained_layout=True)
fig2=category_scatter(x='Average Area', y='Circular blobs', label_col='Class', data=df, legend_loc='upper left')
plt.ylabel("Circular Blobs")
plt.xlabel("Average Area")
plt.title("Average Area vs Circular Blobs")
fig1 = category_scatter(x='Average Area', y='Texture feature - Avg Homogenity', label_col='Class', data=df, legend_loc='upper left')
plt.ylabel("Texture feature - Avg Homogenity")
plt.xlabel("Average Area")
plt.title("Average Area vs Average Homogenity")
fig3 = category_scatter(x='Average Area', y='Texture Feature - Avg Energy', label_col='Class', data=df, legend_loc='upper left')
plt.ylabel("Texture Feature - Avg Energy")
plt.xlabel("Average Area")
plt.title("Average Area vs Texture Feature - Avg Energy")
fig4=category_scatter(x='Average Area', y='Texture feature - Avg Correlation', label_col='Class', data=df, legend_loc='upper left')
plt.ylabel("Texture feature - Avg Correlation")
plt.xlabel("Average Area")
plt.title("Average Area vs Texture feature - Avg Correlation")


fig2=category_scatter(x='Average Area', y='Class', label_col='Class', data=df, legend_loc='lower right')
plt.ylabel("Class Labels")
plt.xlabel("Average Area")
plt.title("Average Area vs Class Labels")  



'''
Number of nuclei	1
Number of overlapping nuclei	2
Average Area	3 x
Avg Compactness	4
Circular blobs	5 x
Non-circular blobs	6
Texture Feature - Avg Energy	7x
Texture feature - Avg Homogenity	8x
Texture feature - Avg Correlation 9 x

'''
# Out:
# '\nNumber of nuclei\t1\nNumber of overlapping nuclei\t2\nAverage Area\t3 x\nAvg Compactness\t4\nCircular blobs\t5 x\nNon-circular blobs\t6\nTexture Feature - Avg Energy\t7x\nTexture feature - Avg Homogenity\t8x\nTexture feature - Avg Correlation 9 x\n\n'
